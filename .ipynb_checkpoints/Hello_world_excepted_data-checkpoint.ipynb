# %%
import pandas as pd
import itertools as it
import numpy as np

#data open using pandas type Dataframe
df_standard = pd.read_csv ('fd_basic_F.csv', encoding = 'cp949')
df_to_add = pd.read_csv ('fd_2018_F.csv', encoding = 'cp949')

#extract_index_code_from_standard_data
index_code_standard=df_standard.drop_duplicates(['code'],keep='first')
index_list = index_code_standard.code.tolist()

#check_matched_data_sorting_function_by_df_to_add
def test_fu_only(code, standard_data, new_data):
    
    #Extract key value from df_to_add
    df_to_add_key = new_data[['Unnamed: 0','y2017','y2018']]

    #df_to_add_listing
    to_add_list =[]
    for i in range(len(new_data)):
        test_index = df_to_add_key.iloc[i,0]
        data_2017 = df_to_add_key.iloc[i,1]
        data_2018 = df_to_add_key.iloc[i,2]
        to_add_list.append([test_index, data_2017, data_2018])

    #df_standard_listing
    standard_list = []
    for i in range(len(standard_data)):
        index_data_2017 = standard_data.iloc[i,6]
        standard_list.append(index_data_2017)
    
    #merge data
    exist_2017=[]
    for i in range(len(standard_list)):
        for j in range(len(to_add_list)):
            index_data = to_add_list[j][1]
            if index_data == standard_list[i] : exist_2017.append(to_add_list[j][0])
    sorting_list=[]
    for i in exist_2017:
        if i not in sorting_list :sorting_list.append(i)    
    
    return sorting_list

#produce_function
test_dummys=[]
for i in range(len(index_list)):
    temp_standard =df_standard[df_standard['code']==index_list[i]]
    temp_new =df_to_add[df_to_add['code']==index_list[i]]
    exist_2017_data = test_fu_only(index_list,temp_standard,temp_new)
    test_dummys.append(exist_2017_data)

#data_conversion    
to_except_datas=list(it.chain(*test_dummys))
to_except_datas_nondouble=np.array(my_list).flatten().tolist()
to_except_datas_nondouble.sort()
to_except_datas_nondouble.reverse()

#extract_total_index and remove_matched_data
total_index = df_to_add.index.tolist()

for to_except_list in to_except_datas_nondouble:
    total_index.remove(to_except_list)

#take_DataFrame
non_match_data = df_to_add.loc[total_index,:]
non_match_data.to_excel("Hi_exception.xlsx")
non_match_data
# Out:
#         Unnamed: 0    code   code_a company                              item  \
# 0                0      20  A000020    동화약품                          이자지급(영업)
# 5                5      20  A000020    동화약품                              자본총계
# 6                6      20  A000020    동화약품                             비지배지분
# 7                7      20  A000020    동화약품                        이익잉여금(결손금)
# 8                8      20  A000020    동화약품                         기타포괄손익누계액
# 9                9      20  A000020    동화약품                              자기주식
# 10              10      20  A000020    동화약품                             자본잉여금
# 11              11      20  A000020    동화약품                               자본금
# 12              12      20  A000020    동화약품                             소유주지분
# 13              13      20  A000020    동화약품                     자본 [abstract]
# 14              14      20  A000020    동화약품                              부채총계
# 15              15      20  A000020    동화약품                            확정급여채무
# 16              16      20  A000020    동화약품                        단기금융상품의 감소
# 17              17      20  A000020    동화약품                         기타비유동금융부채
# 18              18      20  A000020    동화약품                        단기금융상품의 증가
# 19              19      20  A000020    동화약품                         법인세납부(환급)
# 20              20      20  A000020    동화약품                        장기금융상품평가이익
# 21              21      20  A000020    동화약품                  영업활동으로인한자산ㆍ부채의변동
# 22              22      20  A000020    동화약품                      매출채권의 감소(증가)
# 23              23      20  A000020    동화약품                      기타채권의 감소(증가)
# 24              24      20  A000020    동화약품                      재고자산의 감소(증가)
# 25              25      20  A000020    동화약품                    기타유동자산의 감소(증가)
# 26              26      20  A000020    동화약품                      매입채무의 증가(감소)
# 27              27      20  A000020    동화약품                      기타채무의 증가(감소)
# 28              28      20  A000020    동화약품                      기타부채의 증가(감소)
# 29              29      20  A000020    동화약품                    반품충당부채의 증가(감소)
# 30              30      20  A000020    동화약품                     거래보증금의 감소(증가)
# 31              31      20  A000020    동화약품                           퇴직금의 지급
# 32              32      20  A000020    동화약품                    사외적립자산의 감소(증가)
# 33              33      20  A000020    동화약품                          이자수취(영업)
# ...            ...     ...      ...     ...                               ...
# 448881      448881  950170  A950170     JTC                        장기금융상품의 취득
# 448882      448882  950170  A950170     JTC                    장기대여금및수취채권의 취득
# 448883      448883  950170  A950170     JTC                      매입채무의 증가(감소)
# 448884      448884  950170  A950170     JTC                    기타유동부채의 증가(감소)
# 448885      448885  950170  A950170     JTC                 기타비유동금융부채의 증가(감소)
# 448886      448886  950170  A950170     JTC                  기타유동금융부채의 증가(감소)
# 448887      448887  950170  A950170     JTC                    퇴직급여채무의 증가(감소)
# 448888      448888  950170  A950170     JTC                   유동금융리스채권의감소(증가)
# 448889      448889  950170  A950170     JTC                           무형자산상각비
# 448890      448890  950170  A950170     JTC                    대손상각비(대손충당금환입)
# 448891      448891  950170  A950170     JTC             해외사업장환산외환차이(세후기타포괄손익)
# 448892      448892  950170  A950170     JTC     당기손익으로 재분류될 수 있는 항목(세후기타포괄손익)
# 448893      448893  950170  A950170     JTC                             지급수수료
# 448894      448894  950170  A950170     JTC                             광고선전비
# 448895      448895  950170  A950170     JTC                      재고자산의 감소(증가)
# 448896      448896  950170  A950170     JTC                          이자지급(영업)
# 448897      448897  950170  A950170     JTC                         법인세납부(환급)
# 448898      448898  950170  A950170     JTC                          투자활동현금흐름
# 448899      448899  950170  A950170     JTC                         임차보증금의 감소
# 448900      448900  950170  A950170     JTC                         임차보증금의 증가
# 448901      448901  950170  A950170     JTC                           출자금의 감소
# 448902      448902  950170  A950170     JTC                          유형자산의 처분
# 448903      448903  950170  A950170     JTC                          무형자산의 처분
# 448904      448904  950170  A950170     JTC                    장기대여금및수취채권의 처분
# 448905      448905  950170  A950170     JTC                    단기대여금및수취채권의 처분
# 448906      448906  950170  A950170     JTC                    지분법적용 투자지분의 처분
# 448907      448907  950170  A950170     JTC                          유형자산의 취득
# 448908      448908  950170  A950170     JTC                          무형자산의 취득
# 448909      448909  950170  A950170     JTC                          이자수취(영업)
# 448910      448910  950170  A950170     JTC                              재고자산
#
#                   y2018        y2017
# 0                     0            0
# 5       297,401,000,000  296,944,728
# 6           309,606,194            0
# 7       243,147,000,000  239,897,649
# 8         1,464,724,509    4,567,827
# 9         2,521,453,524    2,521,453
# 10       27,069,234,981   27,069,234
# 11       27,931,470,000   27,931,470
# 12      297,091,000,000  296,944,728
# 13                  NaN            0
# 14       73,198,591,231   70,280,404
# 15       12,009,465,140    9,324,456
# 16       56,400,000,000   21,000,000
# 17          246,000,000      239,300
# 18       14,300,000,000   82,000,000
# 19       16,836,656,486    6,114,146
# 20         -535,955,987            0
# 21      -19,456,972,562  -41,682,755
# 22      -12,498,092,285   -8,027,627
# 23         -397,655,152     -909,074
# 24      -11,789,010,851  -13,584,445
# 25          485,983,375   -1,081,562
# 26        8,190,227,828   -3,890,690
# 27        1,160,751,489   -1,658,610
# 28          460,961,501      320,114
# 29        1,210,119,521      466,520
# 30            1,523,653       26,127
# 31         -281,781,641     -343,512
# 32       -6,000,000,000  -13,000,000
# 33        2,088,248,998      974,163
# ...                 ...          ...
# 448881       53,178,000       55,640
# 448882                0    1,543,320
# 448883      144,631,000      118,246
# 448884      -12,069,000      -53,984
# 448885                0         -667
# 448886      829,304,000      -81,639
# 448887       -7,700,000       -1,000
# 448888       64,953,000       45,724
# 448889       21,758,000       16,956
# 448890       16,501,000        3,878
# 448891                0            0
# 448892                0            0
# 448893      802,469,000      720,579
# 448894      160,039,000      218,104
# 448895      204,032,000    2,259,464
# 448896       27,913,000       25,219
# 448897    3,424,493,000    4,985,218
# 448898   -1,073,136,000   -3,105,716
# 448899       14,553,000       16,694
# 448900      151,211,000      127,754
# 448901                0            0
# 448902      158,527,000      122,284
# 448903                0          492
# 448904                0            0
# 448905       86,886,000       44,021
# 448906                0            0
# 448907    1,123,593,000    1,528,266
# 448908        5,120,000       33,927
# 448909          189,000          479
# 448910    5,856,650,000        6,039
#
# [448907 rows x 7 columns]
